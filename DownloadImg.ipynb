# %%
import utils
import constants

# Assuming constants.allowed_units is a predefined list of allowed units
constants.allowed_units = ['gram', 'kilogram', 'litre', 'millilitre', 'centimetre', 'inch', 'foot', 'ounce']

# Example of downloading images
image_links = [
    'https://m.media-amazon.com/images/I/41-NCxNuBxL.jpg',
    'https://m.media-amazon.com/images/I/41-NCxNuBxL.jpg',
    'https://m.media-amazon.com/images/I/417NJrPEk+L.jpg'
]
download_folder = './downloaded_images'

# Download images
download_images(image_links, download_folder, allow_multiprocessing=True)

# Example of parsing a string
try:
    number, unit = parse_string('2.5 litre')
    print(f'Parsed number: {number}, unit: {unit}')
except ValueError as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import utils
#       2 import constants
#       4 # Assuming constants.allowed_units is a predefined list of allowed units
#
# ModuleNotFoundError: No module named 'utils'
